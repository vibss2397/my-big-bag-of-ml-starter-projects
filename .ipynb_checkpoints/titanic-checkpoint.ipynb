# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\Jmd\\Downloads\\train.csv")

# %%
X,y=df.iloc[:,0:],df.iloc[:,1]
X=X.drop('Survived',1)
X=X.drop('Name',1)
X=X.drop('Cabin',1)
X=X.drop('Ticket',1)
X.head()
# Out:
#    PassengerId  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0            1       3    male  22.0      1      0   7.2500        S
# 1            2       1  female  38.0      1      0  71.2833        C
# 2            3       3  female  26.0      0      0   7.9250        S
# 3            4       1  female  35.0      1      0  53.1000        S
# 4            5       3    male  35.0      0      0   8.0500        S

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
X.hist(bins=50,figsize=(20,15))
plt.show()

# %%
from sklearn.preprocessing import LabelBinarizer 
mlb=LabelBinarizer()
df['Sex']=mlb.fit_transform(X['Sex'])

# %%
corr_matrix=df.corr()
corr_matrix['Survived'].sort_values(ascending=False)
# Out:
# Survived       1.000000
# Fare           0.257307
# Parch          0.081629
# PassengerId   -0.005007
# SibSp         -0.035322
# Age           -0.077221
# Pclass        -0.338481
# Sex           -0.543351
# Name: Survived, dtype: float64

# %%
from pandas.plotting import scatter_matrix
attributes = ["Survived","Fare","Parch","PassengerId","SibSp","Age","Pclass","Sex"]
scatter_matrix(df[attributes], figsize=(12, 8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000022D50069A58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D500D1C18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D501342E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D501A0A20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D501FECC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D501FECF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D502E32B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D5031E6A0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000022D4DA72048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D4BF06630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D503DB358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D503E4FD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D504A7160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D50501908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D5056AF60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D505D4320>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000022D50647F98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D506AD908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D506EBDD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D5077C278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D5078C358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D5084A0B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D508A5780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D5090FEB8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000022D50978198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D509ECE10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D50A55780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D50A8DB70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D50B210F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D50B30518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D50BE6EF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D50C4A5F8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000022D50CB6D30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D50D12FD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D50D91DA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D50DF95F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D50E349E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D50EBCF28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D50ED1908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D50F8BC88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000022D50FF0470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D5105AAC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D510BBE48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D51136C18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D511722B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D511E8A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D5123DBE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D5127BA20>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000022D51315048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D5114F358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D513D7E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D5143B5F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D514A4C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D51507FD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D51582C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D515EA518>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000022D516257F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D516B0DA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D5166C160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D5177DBE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D517E0390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D5184CA20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D518ACD68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022D51926940>]], dtype=object)

# %%
# see these graphs,bc koi dhang ka correlation hi ni
